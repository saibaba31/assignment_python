# %% [markdown]
# #### Write a Python Program to implement your own myreduce() function which works exactly like Python's built-in function reduce()

# %%
def myreduce():
    k=0
    for i in range(len(rdlst)):
        k = k + rdlst[i]
        
    print(k)

# %%
rdlst = [4,1,5,7,3]
myreduce()     # reducekind function call
# Out:
# 20

# %% [markdown]
# #### Write a Python program to implement your own myfilter() function which works exactly like Python's built-in function filter()

# %%
### i want to filterout data which divides 5
def myfilter():
    out = []            ##empty list to receive filterout data
    for i in fltlst:
        if i % 5 == 0:
            out.append(i)
            
    print(out)

# %%
fltlst = [2,40,6,8,10,5,3,7,90]

myfilter()        ## function call
# Out:
# [40, 10, 5, 90]

# %% [markdown]
# # ![image.png](attachment:image.png)
#
#
#
#
#
#
#
# # i saw above diagram for reference only  means what are the i/p  and o/p

# %% [markdown]
# ####   Implement List comprehensions to produce the following lists.
# Write List comprehensions to produce the following Lists
# ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]

# %%
["_"+ i + "_"  for i in 'ACADGILD']
# Out:
# ['_A_', '_C_', '_A_', '_D_', '_G_', '_I_', '_L_', '_D_']

# %%
# Write List comprehensions to produce the following Lists
# OUTPUT like ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

[ i * j  for i in 'xyz' for j in range(1,5)]
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
##  Write List comprehensions to produce the following Lists
## output like as ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xx', 'yy', 'zz', 'xxxx', 'yyyy', 'zzzz']


[i * j    for j in range(1,5)     for i in 'xyz']
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
## Write List comprehensions to produce the following Lists
##  [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

[[int(i) + int(j)]    for i in '234'   for j in range(3)]
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
## Write List comprehensions to produce the following Lists
## [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

[ [(int(i)+int(j))    for j in range(4)] for i in '2345']
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
n = []
m = []
for j in range(4):
    for i in '2345':
        n.append(int(i) + int(j))   
    m.extend([n])
    n = []
print(m)
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
#  Write List comprehensions to produce the following Lists
#       [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

[(j,int(i)) for i in '123'  for j in range(1,4)]
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %% [markdown]
# ### Implement a function longestWord() that takes a list of words and returns the longest one

# %%
def longestword():
    n = []
    i = int(input(" how many words you want to enter:"))
    for j in range(1,i+1):
         n.append( input("enter word " + str(j) + " " ))
   
    max = n[0]                        ## imagination max
    for k in range(i):
        if len(max) <  len(n[k]):     ## comparison
            max = n[k]
    print("the longest word is: " ,max)
    
longestword()
# Out:
#  how many words you want to enter:5
# enter word 1 small
# enter word 2 big
# enter word 3 bigger
# enter word 4 biggest
# enter word 5 largest
# the longest word is:  biggest

# %% [markdown]
# ###  Write a Python Program(with class concepts) to find the area of the triangle using the below formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass.

# %%
class Basetriangle:
    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c
        
    
class Derivedarea(Basetriangle):
    def __init__(self, *args):
        super(Derivedarea, self).__init__(*args)
    def area(self):
        self.s = (self.a +self.b + self.c) / 2
        self.area = (self.s * (self.s-self.a) * (self.s-self.b) *(self.s-self.c)) ** 0.5
        print("perimeter is: ", str(self.s) + "\n" + "triangle area is ",str(self.area))
   
dobj = Derivedarea(8,7,5)
dobj.area()        # function call
# Out:
# perimeter is:  10.0
# triangle area is  17.320508075688775

# %% [markdown]
# ####  Write a function filter_long_words() that takes a list of words and an integer n and returns  the list of words that are longer than n.

# %%
def filter_long_words():
    n = []
    m = []
    i = int(input(" how many words you want to enter"))
    for j in range(1,i+1):
         n.append( input("enter word " + str(j) + " " ))
    lenword = int(input("desired word minimum length  "))
    for k in range(i):
        if  len(n[k]) > lenword :
            m.append(n[k])
    print(m)
    
filter_long_words()
# Out:
#  how many words you want to enter5
# enter word 1 int
# enter word 2 small int
# enter word 3 tiny int
# enter word 4 big int
# enter word 5 float
# desired word minimum length 5
# ['small int', 'tiny int', 'big int']

# %% [markdown]
# ####  Write a Python program using function concept that maps list of words into a list of integers  representing the lengths of the corresponding words .
#       Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
#        Here 2,3 and 4 are the lengths of the words in the list.

# %%
lisst = ['ab','cde','erty']

list(map(lambda x : len(x) , lisst ))
# Out:
# [2, 3, 4]

# %% [markdown]
# ####  Write a Python function which takes a character (i.e. a string of length 1) and
# returns True if it is a vowel, False otherwise.

# %%
def funcstrvow():
    while True:
        try:
            i= input("enter the single character: ")
            if len(i) > 1:
                raise valueError("you didnot enter single character")
                
               
        except:
            print("you didnot enter single character , please enter again")
            continue
        
        else:
            if len(i) == 1:
                if i == 'a' or 'e' or 'i' or 'o' or 'u' or 'A' or 'E' or 'I' or 'O' or 'U':
                    return True
                else:
                    return False
            break
        
    

funcstrvow()      #function call
# Out:
# enter the single character: 'd'
# you didnot enter single character , please enter again
# enter the single character: f
# True
